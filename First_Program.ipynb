# %% [markdown]
# <a href="https://colab.research.google.com/github/Siam0827/Skill-Morph/blob/main/First_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome Program!

# %% [markdown]
# # Welcome Program

# %%
print("Welcome to Skill Morph !")
# Out:
# Welcome to Skill Morph !

# %% [markdown]
# # 2nd section

# %% [markdown]
# ## 2nd Section

# %% [markdown]
# **2nd Section**
